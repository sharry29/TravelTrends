# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json("reviews.json")

# %%
df.head()
# Out:
#                                title_text  \
# 0                                Alpacas!
# 1    A fun activity for a girls' trip....
# 2  Love of animals, scenery, tranquility!
# 3                            A must visit
# 4    Great experience for our young kids!
#
#                                          review_link reviewer_name  \
# 0  /ShowUserReviews-g35418-d5006734-r513976440-Se...         cln96
# 1  /ShowUserReviews-g35418-d5006734-r512382508-Se...       Kathy F
# 2  /ShowUserReviews-g35418-d5006734-r512274678-Se...       Helen S
# 3  /ShowUserReviews-g35418-d5006734-r511043958-Se...       pjerret
# 4  /ShowUserReviews-g35418-d5006734-r509512010-Se...         Tim B
#
#   reviewer_handle date_string                    hometown  \
# 0           cln96    Aug 2017     Newman Lake, Washington
# 1       kathyf911    Aug 2017             Meridian, Idaho
# 2   helensR1546QJ    Aug 2017           Crofton, Maryland
# 3         pjerret    Aug 2017  Spokane Valley, Washington
# ...

# %%
df.shape
# Out:
# (345, 13)

# %%
df['review_id'] = df['review_link'].str.extract(r'r(\d+)')

# %%
df = df.set_index("review_id")

# %%
df.head()
# Out:
#                                        title_text  \
# review_id
# 513976440                                Alpacas!
# 512382508    A fun activity for a girls' trip....
# 512274678  Love of animals, scenery, tranquility!
# 511043958                            A must visit
# 509512010    Great experience for our young kids!
#
#                                                  review_link reviewer_name  \
# review_id
# 513976440  /ShowUserReviews-g35418-d5006734-r513976440-Se...         cln96
# 512382508  /ShowUserReviews-g35418-d5006734-r512382508-Se...       Kathy F
# 512274678  /ShowUserReviews-g35418-d5006734-r512274678-Se...       Helen S
# 511043958  /ShowUserReviews-g35418-d5006734-r511043958-Se...       pjerret
# 509512010  /ShowUserReviews-g35418-d5006734-r509512010-Se...         Tim B
#
#           reviewer_handle date_string                    hometown  \
# review_id
# 513976440           cln96    Aug 2017     Newman Lake, Washington
# ...
